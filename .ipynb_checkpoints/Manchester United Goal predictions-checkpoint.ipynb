# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression

# %%
dataset= pd.read_csv('manchester_statistics.csv')

# %%
names = ['Year', 'Scored']

# %%
# shape
print(dataset.shape)
# Out:
# (20, 5)

# %%
print(dataset.head(15))
# Out:
#     Year  Games Played  Scored  Conceded  Goal Difference
# 0   2001            38      87        45               42
# 1   2002            38      74        34               40
# 2   2003            38      64        35               29
# 3   2004            38      58        26               32
# 4   2005            38      72        34               38
# 5   2006            38      83        27               56
# 6   2007            38      80        22               50
# 7   2008            38      68        24               44
# 8   2009            38      86        28               58
# 9   2010            38      78        37               41
# 10  2011            38      89        33               56
# 11  2012            38      86        43               43
# 12  2013            38      64        43               21
# 13  2014            38      62        37               25
# 14  2015            38      49        35               14

# %%
print(dataset.describe())
# Out:
#              Year  Games Played     Scored   Conceded  Goal Difference
# count    20.00000          20.0  20.000000  20.000000         20.00000
# mean   2010.50000          38.0  71.300000  34.700000         36.20000
# std       5.91608           0.0  11.507892   8.118206         13.40699
# min    2001.00000          38.0  49.000000  22.000000         11.00000
# 25%    2005.75000          38.0  64.000000  28.000000         28.00000
# 50%    2010.50000          38.0  70.000000  34.500000         39.00000
# 75%    2015.25000          38.0  80.750000  38.500000         43.25000
# max    2020.00000          38.0  89.000000  54.000000         58.00000

# %%
#visualize
dataset.plot( x='Year', y='Scored')
plt.title ("Man United Stats")

plt.show()

# %%
X = dataset[['Year']]
y = dataset['Scored']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=101)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(model.predict([[2031]]))
# Out:
# [54.21568627]
# /home/nuero/.local/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
